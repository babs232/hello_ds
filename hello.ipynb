# %%
import pandas as pd
import numpy as np
data = pd.read_csv('titanic3.csv')

# %%
data.replace('?', np.nan, inplace= True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# /home/biswa/anaconda3/envs/myenv/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)
data.corr().abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055512
# sibsp     0.027825
# parch     0.082660
# fare      0.244265
# body           NaN

# %%
data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr().abs()[["survived"]]
# Out:
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055512
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# body            NaN
# relatives  0.201719

# %%
data = data[['sex', 'pclass','age','relatives','fare','survived']].dropna()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7464114832535885

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu', input_dim = 5))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 30
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 66
# Trainable params: 66
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6924 - accuracy: 0.5789
# Epoch 2/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6900 - accuracy: 0.5861
# Epoch 3/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6859 - accuracy: 0.5873
# Epoch 4/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6771 - accuracy: 0.6220
# Epoch 5/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6608 - accuracy: 0.7500
# Epoch 6/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6369 - accuracy: 0.7608
# Epoch 7/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6066 - accuracy: 0.7703
# Epoch 8/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5752 - accuracy: 0.7703
# Epoch 9/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5461 - accuracy: 0.7715
# Epoch 10/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5238 - accuracy: 0.7715
# Epoch 11/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5062 - accuracy: 0.7763
# Epoch 12/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4961 - accuracy: 0.7775
# Epoch 13/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4884 - accuracy: 0.7787
# Epoch 14/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4815 - accuracy: 0.7811
# Epoch 15/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4770 - accuracy: 0.7823
# Epoch 16/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4730 - accuracy: 0.7775
# Epoch 17/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4702 - accuracy: 0.7763
# Epoch 18/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4672 - accuracy: 0.7787
# Epoch 19/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4649 - accuracy: 0.7787
# Epoch 20/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4630 - accuracy: 0.7835
# Epoch 21/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4609 - accuracy: 0.7847
# Epoch 22/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4593 - accuracy: 0.7859
# Epoch 23/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4576 - accuracy: 0.7859
# Epoch 24/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4564 - accuracy: 0.7859
# Epoch 25/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4552 - accuracy: 0.7847
# Epoch 26/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4543 - accuracy: 0.7835
# Epoch 27/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4535 - accuracy: 0.7823
# Epoch 28/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4525 - accuracy: 0.7859
# Epoch 29/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4521 - accuracy: 0.7847
# Epoch 30/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4525 - accuracy: 0.7823
# Epoch 31/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4505 - accuracy: 0.7859
# Epoch 32/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4505 - accuracy: 0.7883
# Epoch 33/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4496 - accuracy: 0.7883
# Epoch 34/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4491 - accuracy: 0.7883
# Epoch 35/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4486 - accuracy: 0.7943
# Epoch 36/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4486 - accuracy: 0.7955
# Epoch 37/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4487 - accuracy: 0.7907
# Epoch 38/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4478 - accuracy: 0.7931
# Epoch 39/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4474 - accuracy: 0.7955
# Epoch 40/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4472 - accuracy: 0.7931
# Epoch 41/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4472 - accuracy: 0.7883
# Epoch 42/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4469 - accuracy: 0.7907
# Epoch 43/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4465 - accuracy: 0.7919
# Epoch 44/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4463 - accuracy: 0.7919
# Epoch 45/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4459 - accuracy: 0.7883
# Epoch 46/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4462 - accuracy: 0.7931
# Epoch 47/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4454 - accuracy: 0.7943
# Epoch 48/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4456 - accuracy: 0.7883
# Epoch 49/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4456 - accuracy: 0.7871
# Epoch 50/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4457 - accuracy: 0.7835

# %%
y_pred = np.argmax(model.predict(X_test), axis=-1)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.6124401913875598
